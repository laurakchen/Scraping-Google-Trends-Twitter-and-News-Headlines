# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

# %%
def get_news_reuters(page):
    # url definition
    url = "https://www.reuters.com/news/archive/technologyNews?view=page&page=" + str(page) + "&pageSize=10"

    # Request
    r1 = requests.get(url)
    r1.status_code

    # We'll save in coverpage the cover page content
    coverpage = r1.content

    # Soup
    soup1 = BeautifulSoup(coverpage, "html5lib")

    # News identification
    coverpage_news = soup1.find_all('h3', class_="story-title")
    coverpage_date = soup1.find_all('time')

    # Empty lists for content, links and titles
    list_titles = []
    list_dates = []

    for n in np.arange(0, 10):

        # Getting the title
        title = coverpage_news[n].get_text()
        list_titles.append(title.replace('\t', '').replace('\n',''))

        # Getting the date
        date = coverpage_date[n].find('span').get_text()
        list_dates.append(date)

        # df_show_info
        df_show_info = pd.DataFrame(
        {'Article Title': list_titles,
        'Article Date': list_dates})

    return (df_show_info)

# %%
list_titles = []
list_dates = []

final_df = pd.DataFrame(
{'Article Title': list_titles,
'Article Date': list_dates})

#append info of each coverpage to final dataframe; theguardian has 1900 pages
for i in range(1,3276):
    final_df = final_df.append(get_news_reuters(i))

# %%
final_df
# Out:
#                                         Article Title Article Date
# 0   \n\t\t\t\t\t\t\t\tTesla denies reports of firi...   7:46pm EDT
# 1   \n\t\t\t\t\t\t\t\tIn cloud clash with Alibaba,...   7:05pm EDT
# 2   \n\t\t\t\t\t\t\t\tFacebook hit with complaint ...   6:23pm EDT
# 3   \n\t\t\t\t\t\t\t\tFactbox: More companies join...   6:05pm EDT
# 4   \n\t\t\t\t\t\t\t\tBrazil central bank chief sa...   5:44pm EDT
# ..                                                ...          ...
# 5   \n\t\t\t\t\t\t\t\tGoogle makes a point on gay ...  Feb 07 2014
# 6   \n\t\t\t\t\t\t\t\tIBM explores sale of semicon...  Feb 06 2014
# 7   \n\t\t\t\t\t\t\t\t'Loeb effect' buoys social m...  Feb 06 2014
# 8   \n\t\t\t\t\t\t\t\tActivision earnings beat tar...  Feb 06 2014
# 9   \n\t\t\t\t\t\t\t\tAnalysis: Twitter must move ...  Feb 06 2014
#
# [32750 rows x 2 columns]

# %%
final_df.to_csv('reuterstech_headlines_dataset.csv')
