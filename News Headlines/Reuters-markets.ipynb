# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

# %%
def get_news_reuters(page):
    # url definition
    url = "https://www.reuters.com/news/archive/marketsnews?view=page&page=" + str(page) + "&pageSize=10"

    # Request
    r1 = requests.get(url)
    r1.status_code

    # We'll save in coverpage the cover page content
    coverpage = r1.content

    # Soup
    soup1 = BeautifulSoup(coverpage, "html5lib")

    # News identification
    coverpage_news = soup1.find_all('h3', class_="story-title")
    coverpage_date = soup1.find_all('time')

    # Empty lists for content, links and titles
    list_titles = []
    list_dates = []

    for n in np.arange(0, 10):

        # Getting the title
        title = coverpage_news[n].get_text()
        list_titles.append(title.replace('\t', '').replace('\n',''))

        # Getting the date
        date = coverpage_date[n].find('span').get_text()
        list_dates.append(date)

        # df_show_info
        df_show_info = pd.DataFrame(
        {'Article Title': list_titles,
        'Article Date': list_dates})

    return (df_show_info)

# %%
get_news_reuters(100)
# Out:
#                                        Article Title Article Date
# 0  Yuan flirts with 2-month high before dollar de...  Jun 24 2020
# 1  GLOBAL MARKETS-Asia stocks at 4-mth top as mar...  Jun 24 2020
# 2  FOREX-Dollar squeezed as data stokes economic ...  Jun 24 2020
# 3  With contracts canceled and debts mounting, of...  Jun 24 2020
# 4  Nikkei rises tracking Wall St rally; coronavir...  Jun 24 2020
# 5  China to extend waiver on port construction fe...  Jun 23 2020
# 6                 Morning News Call - India, June 24  Jun 23 2020
# 7  GLOBAL MARKETS-Asia stocks touch 4-month top o...  Jun 23 2020
# 8  FOREX-Dollar wobbly as PMI data stokes hopes f...  Jun 23 2020
# 9  Australia's FAR says Senegalese unit in defaul...  Jun 23 2020

# %%
list_titles = []
list_dates = []

final_df = pd.DataFrame(
{'Article Title': list_titles,
'Article Date': list_dates})

#append info of each coverpage to final dataframe; theguardian has 1900 pages
for i in range(1,3277):
    final_df = final_df.append(get_news_reuters(i))

# %%
final_df
# Out:
#                                         Article Title Article Date
# 0              PRESS DIGEST- Financial Times - July 3   8:47pm EDT
# 1   MEDIA-Hedge funds Citadel, Millennium and Baly...   8:33pm EDT
# 2   Japan's service sector slump eases as pandemic...   8:30pm EDT
# 3   FOREX-Dollar in narrow range as U.S. virus cas...   8:24pm EDT
# 4              PRESS DIGEST-British Business - July 3   8:24pm EDT
# ..                                                ...          ...
# 5   TREASURIES-U.S. bond prices pare gains as Wall...  Aug 28 2019
# 6   Britain is reneging on its Irish border pledge...  Aug 28 2019
# 7   FOREX-Dollar ticks up, but yen holds gains as ...  Aug 28 2019
# 8   UPDATE 3-Coty sees revenue improving as turnar...  Aug 28 2019
# 9   US STOCKS-Wall Street flat on recession fears,...  Aug 28 2019
#
# [32760 rows x 2 columns]

# %%
final_df.to_csv('reutersmarkets_headlines_dataset.csv')
